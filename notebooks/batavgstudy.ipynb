# %% [markdown]
# # Batting Average Control Project
#
# ### Purpose
# This project explores how much control hitters have over their batting average and their BABIP.
# We’ll analyze MLB Statcast/FanGraphs data and test relationships between underlying stats, plate discipline, batted ball profiles and batting average stability.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pybaseball import batting_stats

# Example: get all batting stats for 2023 season
df = batting_stats(2023)

# Keep only the variables we care about
cols = ["Name", "Team", "G", "PA", "AVG", "BABIP", "BB%", "K%", "HR/FB", "LD%", "GB%", "FB%"]
df = df[cols]

# Look at all available columns in this dataset
df.columns.tolist()
df.head()
# Out:
#                Name Team    G   PA    AVG  BABIP    BB%     K%  HR/FB    LD%  \
# 1  Ronald Acuna Jr.  ATL  159  735  0.337  0.338  0.109  0.114  0.240  0.201
# 5   Freddie Freeman  LAD  161  730  0.331  0.370  0.099  0.166  0.150  0.276
# 3      Mookie Betts  LAD  152  693  0.307  0.316  0.139  0.154  0.167  0.237
# 0     Shohei Ohtani  LAA  135  599  0.304  0.342  0.152  0.239  0.312  0.182
# 4        Matt Olson  ATL  162  720  0.283  0.302  0.144  0.232  0.278  0.178
#
#      GB%    FB%
# 1  0.495  0.304
# 5  0.353  0.370
# 3  0.278  0.485
# 0  0.423  0.395
# 4  0.387  0.436
